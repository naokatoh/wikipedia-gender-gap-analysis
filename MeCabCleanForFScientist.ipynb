# %%
# !pip install mecab-python3

# !pip install unidic-lite
# !pip install japanize-matplotlib

# %%
import MeCab
import unidic
import sys
import re
import unicodedata
import matplotlib.pyplot as plt
import tqdm
import japanize_matplotlib
import os
import collections
import glob
import pandas as pd

# %%
# Check if MeCab works
# t = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')

t = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')

sentence = 'すもももももももものうち'
print(t.parse(sentence))
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ
# EOS

# %% [markdown]
# ### Here is a translation
# - すもも	名詞 (= noun),一般 (=general),*,*,*,*,すもも,スモモ,スモモ
# - も	助詞 (=particle) ,係助詞 (=binding particle),*,*,*,*,も,モ,モ
# - もも	名詞 (= noun),一般 (=general),*,*,*,*,もも,モモ,モモ
# - も	助詞 (=particle) ,係助詞 (=binding particle),*,*,*,*,も,モ,モ
# - もも	名詞 (= noun),一般 (=general),*,*,*,*,もも,モモ,モモ
# - の	助詞 (=particle) ,連体化(=attributive),*,*,*,*,の,ノ,ノ
# - うち	名詞(=noun),非自立(=non-indipendent),副詞可能(adverb)=,*,*,*,うち,ウチ,ウチ

# %%
#create the list of meaningless words such as "that" "year" "what" etc... 
with open("stopwords.txt", encoding='UTF-8') as f:
    stopwords = f.read().split("\n")
print(stopwords)
# Out:
# ['あそこ', 'あたり', 'あちら', 'あっち', 'あと', 'あな', 'あなた', 'あれ', 'いくつ', 'いつ', 'いま', 'いや', 'いろいろ', 'うち', 'おおまか', 'おまえ', 'おれ', 'がい', 'かく', 'かたち', 'かやの', 'から', 'がら', 'きた', 'くせ', 'ここ', 'こっち', 'こと', 'ごと', 'こちら', 'ごっちゃ', 'これ', 'これら', 'ごろ', 'さまざま', 'さらい', 'さん', 'しかた', 'しよう', 'すか', 'ずつ', 'すね', 'すべて', 'ぜんぶ', 'そう', 'そこ', 'そちら', 'そっち', 'そで', 'それ', 'それぞれ', 'それなり', 'たくさん', 'たち', 'たび', 'ため', 'だめ', 'ちゃ', 'てん', 'とおり', 'とき', 'どこ', 'どこか', 'ところ', 'どちら', 'どっか', 'どっち', 'どれ', 'なか', 'なかば', 'なに', 'など', 'なん', 'はじめ', 'はず', 'はるか', 'ひと', 'ひとつ', 'ふく', 'ぶり', 'べつ', 'へん', 'ぺん', 'ほう', 'ほか', 'まさ', 'まし', 'まとも', 'まま', 'みたい', 'みつ', 'みなさん', 'みんな', 'もと', 'もの', 'もん', 'やつ', 'よう', 'よそ', 'わけ', 'わたし', '', 'ハイ', '', '', '上', '中', '下', '字', '', '', '年', '月', '日', '時', '分', '秒', '週', '火', '水', '木', '金', '土', '国', '都', '道', '府', '県', '市', '区', '町', '村', '', '', '各', '第', '方', '何', '的', '度', '文', '者', '体', '人', '他', '今', '部', '課', '係', '外', '類', '達', '気', '室', '口', '誰', '用', '界', '会', '首', '別', '話', '私', '屋', '店', '家', '場', '等', '見', '際', '観', '段', '略', '例', '系', '論', '形', '間', '地', '員', '線', '点', '書', '品', '力', '法', '感', '作', '元', '手', '数', '子', '内', '楽', '喜', '怒', '哀', '輪', '頃', '化', '境', '俺', '奴', '高', '校', '婦', '伸', '紀', '誌', 'レ', '行', '列', '事', '士', '台', '集', '様', '所', '歴', '器', '名', '情', '連', '毎', '式', '簿', '', '', '', '', '回', '匹', '個', '席', '束', '歳', '目', '通', '面', '円', '玉', '枚', '', '前', '後', '左', '右', '次', '先', '', '春', '夏', '秋', '冬', '', '', '', '一', '二', '三', '四', '五', '六', '七', '八', '九', '十', '百', '千', '万', '億', '兆', '', '', '下記', '上記', '時間', '今回', '前回', '場合', '一つ', '年生', '自分', 'ヶ所', 'ヵ所', 'カ所', '箇所', 'ヶ月', 'ヵ月', 'カ月', '箇月', '名前', '本当', '確か', '時点', '全部', '関係', '近く', '方法', '我々', '違い', '多く', '扱い', '新た', 'その後', '半ば', '結局', '様々', '以前', '以後', '以降', '未満', '以上', '以下', '幾つ', '毎日', '自体', '向こう', '何人', '手段', '同じ', '感じ', '*', 'する', 'なる', 'の', 'れる', 'いる', 'ある', 'せる', 'いく', 'おる', 'せる', 'よる', 'くる', 'られる', '', '']

# %%
#read all the file in "F:\Wikipedia\wikiextractor-master\wikiextractor\f_scientist"

# %%
def count_word(text, pos_tags, stopwords):
    
    words_list = []
    tagger = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')
    
    node = tagger.parseToNode(text)

    while node:
        features = node.feature.split(",")
        base = features[6]
        pos_tag = features[0]
        
        # remove "stopwords"
        if pos_tag in pos_tags and base not in stopwords:
            words_list.append((base, pos_tag))
            

        node = node.next
    count = collections.Counter(words_list)

    return count

# chart
# def draw_barh_chart(y, width):
#     fig, ax = plt.subplots(figsize=(8, 4.5))
#     ax.barh(y, width)

# #     fig.savefig("word_count.png")


if __name__ == "__main__":
    # read files
    #change HERE to try other files
    with open("F:\Wikipedia\wikiextractor-master\wikiextractor\f_scientist\A・グレイス・クック", 'r', encoding='UTF-8') as files:
        text = files.read()
    
    # read stopwords
    with open("stopwords.txt",encoding='UTF-8') as f:
        stopwords = f.read().split("\n")

    pos_tags = ["名詞", "動詞", "形容詞"] 
    #  ["名詞", "動詞", "形容詞"]=  ["noun", "verb", "adj"]
    count = count_word(text, pos_tags, stopwords)

top100_words = count.most_common(100)
top100_words
    
top100 = pd.DataFrame(top100_words, columns = ['word_tuple', "count"]) 
top100
   
    
    
# Draw a chart
#top_words = count.most_common(10)
#words = list(map(lambda x: x[0], top_words))[::-1]
#counts = list(map(lambda x: x[1], top_words))[::-1]
#draw_barh_chart(words, counts)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28896/2544939847.py in <module>
#      32     # read files
#      33     #change HERE to try other files
# ---> 34     with open("F:\Wikipedia\wikiextractor-master\wikiextractor\f_scientist\A・グレイス・クック", 'r', encoding='UTF-8') as files:
#      35         text = files.read()
#      36
#
# OSError: [Errno 22] Invalid argument: 'F:\\Wikipedia\\wikiextractor-master\\wikiextractor\x0c_scientist\\A・グレイス・クック'

# %%
top100.head()

# %%
top100 = top100.assign(
    word = lambda x: x["word_tuple"].apply(lambda wt: wt[0]),
    pos = lambda x: x["word_tuple"].apply(lambda wt: wt[1])
)

# %%
top100.head()

# %%
def count_word(text, pos_tags, stopwords):
    
    words_list = []
    tagger = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')
    
    node = tagger.parseToNode(text)

    while node:
        features = node.feature.split(",")
        base = features[6]
        pos_tag = features[0]
        
        # remove "stopwords"
        if pos_tag in pos_tags and base not in stopwords:
            words_list.append((base, pos_tag))
            

        node = node.next
    count = collections.Counter(words_list)

    return count

# %%
file_list = glob.glob("F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist/*")

# %%
file_list[:5]
# Out:
# ['F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist\\エイダ・ラブレス',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist\\アイン・ランド',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist\\ウィリアム・ハーシェル',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist\\ヒルデガルト・フォン・ビンゲン',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist\\アンゲラ・メルケル']

# %%
# read stopwords
with open("stopwords.txt",encoding='UTF-8') as f:
    stopwords = f.read().split("\n")

pos_tags = ["名詞", "動詞", "形容詞"] 
#  ["名詞", "動詞", "形容詞"]=  ["noun", "verb", "adj"]

# %%
dfs = []

# %%
for f in file_list:
    with open(f, 'r', encoding='UTF-8') as file:
        text = file.read()
    
    f_name = f.split("\\")[-1]
    
    count = count_word(text, pos_tags, stopwords)
    
    #top100_words = count.most_common(100)
    all_words = count.items()
    
    all_words_df = (
        pd
        .DataFrame(all_words, columns = ['word_tuple', "count"])
        .assign(
            word = lambda x: x["word_tuple"].apply(lambda wt: wt[0]),
            pos = lambda x: x["word_tuple"].apply(lambda wt: wt[1]),
            file_name = f_name
        )
        .sort_values("count", ascending=False)
    )
    #print(top100.head())
    full_csv_file = "F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist/new_csvs/" + f_name + "_words.csv"
    #print(f_name)
    all_words_df.to_csv(full_csv_file, index=None)
    dfs.append(all_words_df)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_28896/2385737577.py in <module>
#       1 for f in file_list:
# ----> 2     with open(f, 'r', encoding='UTF-8') as file:
#       3         text = file.read()
#       4
#       5     f_name = f.split("\\")[-1]
#
# PermissionError: [Errno 13] Permission denied: 'F:/Wikipedia/wikiextractor-master/wikiextractor/f_scientist\\csvs'

# %%
overall = (
    pd
    .concat(dfs)
    .groupby(["word", "pos"])
    .pipe(
        lambda grp: pd.DataFrame({
            "total": grp["count"].sum(),
            "articles": grp["file_name"].nunique()
        }))
    .reset_index()
    .sort_values("total", ascending=False)
)

# %%
overall[overall.pos == "名詞"].head(60)
# Out:
#        word pos  total  articles
# 16626    研究  名詞   4261       966
# 9420     大学  名詞   2918       849
# 9888      学  名詞   2900       878
# 12771    教授  名詞   2275       867
# 13064    日本  名詞   2220       804
# 11398    彼女  名詞   1987       304
# 9708     女性  名詞   1720       494
# 16896    科学  名詞   1373       508
# 7839     博士  名詞   1356       751
# 9930     学者  名詞   1318       833
# 12785    教育  名詞   1256       445
# 16699    社会  名詞   1137       374
# 16893     科  名詞   1095       514
# 7762     卒業  名詞    961       673
# 9424    大学院  名詞    897       500
# 9914     学校  名詞    803       384
# 9892     学会  名詞    780       302
# 11677     性  名詞    753       278
# 1572   アメリカ  名詞    749       272
# 8096     取得  名詞    740       479
# 16627   研究所  名詞    734       327
# 19397    論文  名詞    709       323
# 16419    看護  名詞    704        83
# 10402    専門  名詞    687       549
# 17438    経済  名詞    663       184
# 19671     賞  名詞    662       302
# 11551    心理  名詞    660       172
# 9786     委員  名詞    636       237
# 8264      号  名詞    615       346
# 8619     哲学  名詞    590       156
# 19354    課程  名詞    579       390
# 8145     受賞  名詞    579       298
# 14878    活動  名詞    575       270
# 8906     国際  名詞    538       266
# 13754    東京  名詞    536       279
# 3300    ドイツ  名詞    528       132
# 19109    言語  名詞    527       149
# 7684     医学  名詞    520       213
# 8450     名誉  名詞    519       325
# 12823    数学  名詞    517       121
# 11344    当時  名詞    513       213
# 10750     州  名詞    509       226
# 17458    結婚  名詞    503       289
# 5378     世界  名詞    503       245
# 9601      夫  名詞    502       252
# 14069    植物  名詞    490       101
# 9938     学部  名詞    472       288
# 15571    物理  名詞    469       133
# 12855    文化  名詞    465       208
# 7138     出身  名詞    459       408
# 7123     出版  名詞    456       200
# 16207    発表  名詞    452       217
# 15518     父  名詞    446       204
# 16140    病院  名詞    441       155
# 19447    講師  名詞    435       311
# 13271    昭和  名詞    429       111
# 16208    発見  名詞    413       153
# 3905   フランス  名詞    412       110
# 21632    高等  名詞    411       235
# 9922     学科  名詞    410       276

# %%
overall[overall.pos == "動詞"].head(60)
# Out:
#        word pos  total  articles
# 18661    行う  動詞    910       401
# 8110    受ける  動詞    757       316
# 7553    務める  動詞    748       420
# 883     できる  動詞    634       216
# 15839  生まれる  動詞    547       439
# 16547    知る  動詞    486       293
# 9890     学ぶ  動詞    473       289
# 11483    得る  動詞    451       210
# 12373    持つ  動詞    417       218
# 17532   続ける  動詞    363       184
# 17429    経る  動詞    351       294
# 17838   考える  動詞    338       154
# 6551     働く  動詞    335       182
# 13417    書く  動詞    327       136
# 81       いう  動詞    306       142
# 20024   述べる  動詞    289       128
# 5365    与える  動詞    271       137
# 8548     呼ぶ  動詞    254       128
# 9776    始める  動詞    243       159
# 18927    見る  動詞    234       123
# 19100    言う  動詞    218       107
# 20381    選ぶ  動詞    218       141
# 16686    示す  動詞    214       119
# 19269   認める  動詞    197       124
# 19296    語る  動詞    197        92
# 8485     含む  動詞    189       126
# 12082    戻る  動詞    183       105
# 6263     使う  動詞    176       109
# 8084   取り組む  動詞    170       119
# 14636   求める  動詞    163        93
# 12756   教える  動詞    154       106
# 20082    送る  動詞    154        87
# 15914   用いる  動詞    152       107
# 11642    思う  動詞    146        80
# 5743   亡くなる  動詞    133        88
# 16928    移る  動詞    132       107
# 6218     作る  動詞    130        99
# 18670    行く  動詞    127        78
# 6722     入る  動詞    125        83
# 12542    描く  動詞    119        66
# 928      とる  動詞    118        94
# 19151   訪れる  動詞    118        74
# 20287   過ごす  動詞    116        94
# 9082    基づく  動詞    113        73
# 14431    残す  動詞    111        85
# 20851   関わる  動詞    111        85
# 11900   感じる  動詞    110        62
# 20220    進む  動詞    109        86
# 7094    出会う  動詞    107        77
# 17959    育つ  動詞    107        91
# 7090     出る  動詞    105        73
# 17530    続く  動詞    103        71
# 7087     出す  動詞    102        66
# 621     しまう  動詞     99        57
# 20804    開く  動詞     96        68
# 8092     取る  動詞     94        67
# 16330   目指す  動詞     92        71
# 15120    渡る  動詞     91        71
# 7444    加える  動詞     90        65
# 21060   集める  動詞     87        64

# %%
overall[overall.pos == "形容詞"].head(60)
# Out:
#         word  pos  total  articles
# 936       ない  形容詞    586       218
# 11289     強い  形容詞    166       108
# 9300      多い  形容詞    158        93
# 21570     高い  形容詞    147        97
# 12942    新しい  形容詞    142        90
# 9362     大きい  形容詞    106        76
# 18296     若い  形容詞     92        67
# 20732     長い  形容詞     83        62
# 18214     良い  形容詞     82        49
# 15034     深い  形容詞     79        55
# 11060     広い  形容詞     75        63
# 10518    少ない  形容詞     58        44
# 11041     幼い  形容詞     56        46
# 1394      よい  形容詞     55        39
# 15376     無い  形容詞     47        28
# 7946     厳しい  形容詞     46        34
# 14304    正しい  形容詞     42        28
# 19980     近い  形容詞     41        35
# 1346     やすい  形容詞     40        32
# 11773     悪い  形容詞     40        27
# 6130      低い  形容詞     39        33
# 15305    激しい  形容詞     38        29
# 19014    親しい  形容詞     31        26
# 79        いい  形容詞     31        21
# 17714    美しい  形容詞     31        23
# 21112    難しい  形容詞     31        25
# 13135     早い  形容詞     29        26
# 13196    明るい  形容詞     28        13
# 10926    幅広い  形容詞     26        20
# 1164     ほしい  形容詞     24        21
# 15731    珍しい  形容詞     24        19
# 11276     弱い  形容詞     21        19
# 19574    貧しい  形容詞     21        16
# 8183      古い  形容詞     20        19
# 166      うまい  形容詞     16        15
# 20252     遅い  形容詞     15        14
# 17364  素晴らしい  形容詞     15        11
# 19258    詳しい  形容詞     15        14
# 6193    余儀ない  形容詞     15        15
# 12825   数少ない  形容詞     14        12
# 7894      厚い  形容詞     14         7
# 389      がたい  形容詞     13         9
# 14272    欲しい  形容詞     13        12
# 10433    小さい  形容詞     13         9
# 20334     遠い  形容詞     12        10
# 14131    楽しい  形容詞     12        11
# 16576     短い  形容詞     12        12
# 18313    苦しい  形容詞     12        11
# 20533     重い  形容詞     12        11
# 6569     優しい  形容詞     11        10
# 18479    著しい  形容詞     11        11
# 8833      固い  形容詞     10         6
# 12821    数多い  形容詞     10        10
# 978      にくい  形容詞     10         8
# 8453     名高い  形容詞      9         8
# 17156    等しい  形容詞      9         8
# 875      づらい  形容詞      9         5
# 1086     ひどい  形容詞      9         9
# 19710     赤い  形容詞      8         7
# 13344     暗い  形容詞      8         7

# %%
overall.to_csv("f_scientist_text_overall.csv", index= False)

# %%
pd.read_csv("f_scientist_text_overall.csv")
# Out:
#         word pos  total  articles
# 0         研究  名詞   4261       966
# 1         大学  名詞   2918       849
# 2          学  名詞   2900       878
# 3         教授  名詞   2275       867
# 4         日本  名詞   2220       804
# ...      ...  ..    ...       ...
# 21810     武利  名詞      1         1
# 21811     武史  名詞      1         1
# 21812  中日新聞社  名詞      1         1
# 21813     武官  名詞      1         1
# 21814      ｍ  名詞      1         1
#
# [21815 rows x 4 columns]
