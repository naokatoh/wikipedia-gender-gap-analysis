# %%
# !pip install mecab-python3

# !pip install unidic-lite
# !pip install japanize-matplotlib

# %%
import MeCab
import unidic
import sys
import re
import unicodedata
import matplotlib.pyplot as plt
import tqdm
import japanize_matplotlib
import os
import collections
import glob
import pandas as pd

# %%
# Check if MeCab works
# t = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')

t = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')

sentence = 'すもももももももものうち'
print(t.parse(sentence))
# Out:
# すもも	名詞,一般,*,*,*,*,すもも,スモモ,スモモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# も	助詞,係助詞,*,*,*,*,も,モ,モ
# もも	名詞,一般,*,*,*,*,もも,モモ,モモ
# の	助詞,連体化,*,*,*,*,の,ノ,ノ
# うち	名詞,非自立,副詞可能,*,*,*,うち,ウチ,ウチ
# EOS

# %% [markdown]
# ### Here is a translation
# - すもも	名詞 (= noun),一般 (=general),*,*,*,*,すもも,スモモ,スモモ
# - も	助詞 (=particle) ,係助詞 (=binding particle),*,*,*,*,も,モ,モ
# - もも	名詞 (= noun),一般 (=general),*,*,*,*,もも,モモ,モモ
# - も	助詞 (=particle) ,係助詞 (=binding particle),*,*,*,*,も,モ,モ
# - もも	名詞 (= noun),一般 (=general),*,*,*,*,もも,モモ,モモ
# - の	助詞 (=particle) ,連体化(=attributive),*,*,*,*,の,ノ,ノ
# - うち	名詞(=noun),非自立(=non-indipendent),副詞可能(adverb)=,*,*,*,うち,ウチ,ウチ

# %%
#create the list of meaningless words such as "that" "year" "what" etc... 
with open("stopwords.txt", encoding='UTF-8') as f:
    stopwords = f.read().split("\n")
print(stopwords)
# Out:
# ['あそこ', 'あたり', 'あちら', 'あっち', 'あと', 'あな', 'あなた', 'あれ', 'いくつ', 'いつ', 'いま', 'いや', 'いろいろ', 'うち', 'おおまか', 'おまえ', 'おれ', 'がい', 'かく', 'かたち', 'かやの', 'から', 'がら', 'きた', 'くせ', 'ここ', 'こっち', 'こと', 'ごと', 'こちら', 'ごっちゃ', 'これ', 'これら', 'ごろ', 'さまざま', 'さらい', 'さん', 'しかた', 'しよう', 'すか', 'ずつ', 'すね', 'すべて', 'ぜんぶ', 'そう', 'そこ', 'そちら', 'そっち', 'そで', 'それ', 'それぞれ', 'それなり', 'たくさん', 'たち', 'たび', 'ため', 'だめ', 'ちゃ', 'てん', 'とおり', 'とき', 'どこ', 'どこか', 'ところ', 'どちら', 'どっか', 'どっち', 'どれ', 'なか', 'なかば', 'なに', 'など', 'なん', 'はじめ', 'はず', 'はるか', 'ひと', 'ひとつ', 'ふく', 'ぶり', 'べつ', 'へん', 'ぺん', 'ほう', 'ほか', 'まさ', 'まし', 'まとも', 'まま', 'みたい', 'みつ', 'みなさん', 'みんな', 'もと', 'もの', 'もん', 'やつ', 'よう', 'よそ', 'わけ', 'わたし', '', 'ハイ', '', '', '上', '中', '下', '字', '', '', '年', '月', '日', '時', '分', '秒', '週', '火', '水', '木', '金', '土', '国', '都', '道', '府', '県', '市', '区', '町', '村', '', '', '各', '第', '方', '何', '的', '度', '文', '者', '体', '人', '他', '今', '部', '課', '係', '外', '類', '達', '気', '室', '口', '誰', '用', '界', '会', '首', '別', '話', '私', '屋', '店', '家', '場', '等', '見', '際', '観', '段', '略', '例', '系', '論', '形', '間', '地', '員', '線', '点', '書', '品', '力', '法', '感', '作', '元', '手', '数', '子', '内', '楽', '喜', '怒', '哀', '輪', '頃', '化', '境', '俺', '奴', '高', '校', '婦', '伸', '紀', '誌', 'レ', '行', '列', '事', '士', '台', '集', '様', '所', '歴', '器', '名', '情', '連', '毎', '式', '簿', '', '', '', '', '回', '匹', '個', '席', '束', '歳', '目', '通', '面', '円', '玉', '枚', '', '前', '後', '左', '右', '次', '先', '', '春', '夏', '秋', '冬', '', '', '', '一', '二', '三', '四', '五', '六', '七', '八', '九', '十', '百', '千', '万', '億', '兆', '', '', '下記', '上記', '時間', '今回', '前回', '場合', '一つ', '年生', '自分', 'ヶ所', 'ヵ所', 'カ所', '箇所', 'ヶ月', 'ヵ月', 'カ月', '箇月', '名前', '本当', '確か', '時点', '全部', '関係', '近く', '方法', '我々', '違い', '多く', '扱い', '新た', 'その後', '半ば', '結局', '様々', '以前', '以後', '以降', '未満', '以上', '以下', '幾つ', '毎日', '自体', '向こう', '何人', '手段', '同じ', '感じ', '*', 'する', 'なる', 'の', 'れる', 'いる', 'ある', 'せる', 'いく', 'おる', 'せる', 'よる', 'くる', 'られる', '', '']

# %%
#read all the file in "F:\Wikipedia\wikiextractor-master\wikiextractor\f_scientist"

# %%
def count_word(text, pos_tags, stopwords):
    
    words_list = []
    tagger = MeCab.Tagger('-r/nul -d"C:/Program Files (x86)/MeCab/dic/ipadic"')
    
    node = tagger.parseToNode(text)

    while node:
        features = node.feature.split(",")
        base = features[6]
        pos_tag = features[0]
        
        # remove "stopwords"
        if pos_tag in pos_tags and base not in stopwords:
            words_list.append((base, pos_tag))
            

        node = node.next
    count = collections.Counter(words_list)

    return count

# chart
# def draw_barh_chart(y, width):
#     fig, ax = plt.subplots(figsize=(8, 4.5))
#     ax.barh(y, width)

# #     fig.savefig("word_count.png")


# if __name__ == "__main__":
#     # read files
#     #change HERE to try other files
#     with open('F:\Wikipedia\wikiextractor-master\wikiextractor\people\people鈴木みのり (カーリング選手)', 'r', encoding='UTF-8') as files:
#         text = files.read()
    
#     # read stopwords
#     with open("stopwords.txt",encoding='UTF-8') as f:
#         stopwords = f.read().split("\n")

#     pos_tags = ["名詞", "動詞", "形容詞"] 
#     #  ["名詞", "動詞", "形容詞"]=  ["noun", "verb", "adj"]
#     count = count_word(text, pos_tags, stopwords)

# top100_words = count.most_common(100)
# top100_words
    
# top100 = pd.DataFrame(top100_words, columns = ['word_tuple', "count"]) 
# top100
   
    
    
# Draw a chart
#top_words = count.most_common(10)
#words = list(map(lambda x: x[0], top_words))[::-1]
#counts = list(map(lambda x: x[1], top_words))[::-1]
#draw_barh_chart(words, counts)

# %%
file_list = glob.glob("F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater/*")

# %%
file_list[:5]
# Out:
# ['F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater\\河合彩',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater\\大石恵',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater\\伊藤みどり',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater\\中野友加里',
#  'F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater\\八木沼純子']

# %%
# read stopwords
with open("stopwords.txt",encoding='UTF-8') as f:
    stopwords = f.read().split("\n")

pos_tags = ["名詞", "動詞", "形容詞"] 
#  ["名詞", "動詞", "形容詞"]=  ["noun", "verb", "adj"]

# %%
dfs = []

# %%
for f in file_list:
    with open(f, 'r', encoding='UTF-8') as file:
        text = file.read()
    
    f_name = f.split("\\")[-1]
    
    count = count_word(text, pos_tags, stopwords)
    
    #top100_words = count.most_common(100)
    all_words = count.items()
    
    all_words_df = (
        pd
        .DataFrame(all_words, columns = ['word_tuple', "count"])
        .assign(
            word = lambda x: x["word_tuple"].apply(lambda wt: wt[0]),
            pos = lambda x: x["word_tuple"].apply(lambda wt: wt[1]),
            file_name = f_name
        )
        .sort_values("count", ascending=False)
    )
    #CHANGE PATH!!!!!!!
    full_csv_file = "F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater/new_csvs/" + f_name + "_words.csv"
    #print(f_name)
    all_words_df.to_csv(full_csv_file, index=None)
    dfs.append(all_words_df)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20176/1550928799.py in <module>
#       1 for f in file_list:
# ----> 2     with open(f, 'r', encoding='UTF-8') as file:
#       3         text = file.read()
#       4
#       5     f_name = f.split("\\")[-1]
#
# PermissionError: [Errno 13] Permission denied: 'F:/Wikipedia/wikiextractor-master/wikiextractor/femaleFigureSkater\\csv'

# %%
overall = (
    pd
    .concat(dfs)
    .groupby(["word", "pos"])
    .pipe(
        lambda grp: pd.DataFrame({
            "total": grp["count"].sum(),
            "articles": grp["file_name"].nunique()
        }))
    .reset_index()
    .sort_values("total", ascending=False)
)

# %%
overall[overall.pos == "名詞"].head(60)
# Out:
#         word pos  total  articles
# 8804     選手権  名詞   7549      1539
# 3241       位  名詞   7368      1050
# 1469    スケート  名詞   5824      2488
# 1391    シーズン  名詞   5005       903
# 2082   フィギュア  名詞   4248      2466
# 8803      選手  名詞   3708      2509
# 2912      世界  名詞   3239      1022
# 3596      出場  名詞   3185       910
# 3412      優勝  名詞   3069      1038
# 1424    ジュニア  名詞   2459       742
# 968   オリンピック  名詞   2418       933
# 3617      出身  名詞   2377      2288
# 1166   グランプリ  名詞   1999       640
# 1385    シングル  名詞   1901      1503
# 6242       杯  名詞   1837       640
# 4570      女子  名詞   1753      1275
# 3168      代表  名詞   1739      1135
# 2266      ペア  名詞   1667       566
# 4442      大会  名詞   1419       608
# 2022   パートナー  名詞   1350      1144
# 4229      回転  名詞   1327       164
# 1375    シリーズ  名詞   1299       518
# 2693     ロシア  名詞   1217       446
# 6959      獲得  名詞   1215       441
# 4574      女性  名詞   1029       994
# 7609      経歴  名詞    981       979
# 1016     カナダ  名詞    938       352
# 7493      競技  名詞    927       480
# 703   アイスダンス  名詞    922       618
# 2069   ファイナル  名詞    883       309
# 3495     全日本  名詞    844       167
# 1419    ジャンプ  名詞    823       208
# 1010    カップル  名詞    808       301
# 7622      結成  名詞    782       447
# 5178      引退  名詞    771       541
# 4264      国際  名詞    762       493
# 1348     シニア  名詞    709       447
# 1120     クラス  名詞    699       411
# 760     アメリカ  名詞    695       377
# 6449      欧州  名詞    686       290
# 3499      全米  名詞    678       204
# 5973      日本  名詞    654       253
# 7675      総合  名詞    626       217
# 6815      演技  名詞    588       196
# 8715      連続  名詞    587       283
# 3923      参戦  名詞    569       414
# 4503      大陸  名詞    568       265
# 7085      男性  名詞    542       542
# 8118     表彰台  名詞    513       327
# 2131     フリー  名詞    495       150
# 5530       戦  名詞    489       206
# 7695      練習  名詞    488       263
# 2422      ミス  名詞    458       156
# 3650       初  名詞    428       263
# 2471   メダリスト  名詞    424       343
# 6666      活動  名詞    420       279
# 6982      現在  名詞    420       324
# 6129      最高  名詞    418       227
# 2472     メダル  名詞    411       243
# 7596       組  名詞    410       173

# %%
overall[overall.pos == "動詞"].head(60)
# Out:
#       word pos  total  articles
# 6293   果たす  動詞    960       511
# 4605   始める  動詞    767       617
# 7589   終わる  動詞    574       339
# 3467    入る  動詞    536       291
# 7014  生まれる  動詞    433       420
# 416    できる  動詞    340       197
# 8091    行う  動詞    320       211
# 3991   受ける  動詞    313       189
# 7655    続く  動詞    300       179
# 7603    組む  動詞    296       222
# 9221    飾る  動詞    270       193
# 7466    立つ  動詞    202       144
# 6596   決める  動詞    198       126
# 8667    逃す  動詞    179       123
# 7406    移す  動詞    170       138
# 7656   続ける  動詞    151       125
# 45      いう  動詞    147        81
# 3619  出遅れる  動詞    147        93
# 3801   務める  動詞    141        96
# 393    つける  動詞    138        83
# 5348    思う  動詞    131        50
# 7094   留まる  動詞    130        97
# 299    しまう  動詞    129        71
# 2830    上る  動詞    123       106
# 2827   上げる  動詞    120        92
# 8535    跳ぶ  動詞    118        69
# 3584    出す  動詞    109        61
# 5687    持つ  動詞    109        84
# 8364    語る  動詞    106        35
# 7587   終える  動詞    104        89
# 8798    選ぶ  動詞    103        76
# 6512    残す  動詞    103        90
# 9137    響く  動詞    102        72
# 3586    出る  動詞     96        48
# 6440    次ぐ  動詞     95        68
# 5285    得る  動詞     92        65
# 8199    見る  動詞     91        52
# 8191   見せる  動詞     90        49
# 629     もつ  動詞     82        78
# 7607    経る  動詞     81        74
# 8617   迎える  動詞     80        59
# 8034   落とす  動詞     73        57
# 7213   目指す  動詞     71        60
# 6979    現す  動詞     68        65
# 3600   出来る  動詞     67        56
# 6801    滑る  動詞     66        49
# 7886    臨む  動詞     66        52
# 7271    着る  動詞     65        38
# 6595   決まる  動詞     64        48
# 8276    言う  動詞     62        32
# 2824   上がる  動詞     60        48
# 9072   離れる  動詞     58        51
# 9021    除く  動詞     57        53
# 5844   敗れる  動詞     57        45
# 649     やる  動詞     53        23
# 5698    挑む  動詞     53        40
# 3983    取る  動詞     52        35
# 8097    行く  動詞     51        45
# 7237   相次ぐ  動詞     50        36
# 6812   演じる  動詞     50        14

# %%
overall[overall.pos == "形容詞"].head(60)
# Out:
#         word  pos  total  articles
# 438       ない  形容詞    326       206
# 9272      高い  形容詞    164        67
# 4431     大きい  形容詞    116        87
# 4409      多い  形容詞     73        48
# 6859      無い  形容詞     60        53
# 8619      近い  形容詞     56        52
# 5194      強い  形容詞     49        30
# 7938      良い  形容詞     45        27
# 320      すごい  形容詞     37         9
# 44        いい  形容詞     33        12
# 9077     難しい  形容詞     33        23
# 5914     新しい  形容詞     24        21
# 7733     美しい  形容詞     21        15
# 3274    余儀ない  形容詞     20        19
# 7970      若い  形容詞     19        15
# 6976     珍しい  形容詞     17        16
# 3245      低い  形容詞     17        13
# 8917      長い  形容詞     17        16
# 6002      早い  形容詞     17        15
# 6834     激しい  形容詞     13        12
# 5096      幼い  形容詞     12        12
# 6384     楽しい  形容詞     12         4
# 4879     少ない  形容詞     11         9
# 3917     厳しい  形容詞     11         9
# 7568   素晴らしい  形容詞     10         7
# 87      うれしい  形容詞     10         3
# 9123     面白い  形容詞     10         3
# 2840     上手い  形容詞     10         8
# 4844     小さい  形容詞      9         8
# 6713      深い  形容詞      9         8
# 3754     力強い  形容詞      8         8
# 5394     悔しい  形容詞      8         6
# 557      ほしい  形容詞      8         4
# 4631     嬉しい  形容詞      8         3
# 5350  思わしくない  形容詞      7         7
# 665       よい  形容詞      7         4
# 6451     欲しい  形容詞      7         4
# 7579     細かい  形容詞      7         7
# 8591      軽い  形容詞      6         6
# 5876    数少ない  形容詞      6         5
# 7295      短い  形容詞      6         6
# 5105      広い  形容詞      6         5
# 5875     数多い  形容詞      6         6
# 8041     著しい  形容詞      6         6
# 6305    柔らかい  形容詞      5         5
# 180     かわいい  形容詞      5         2
# 86       うまい  形容詞      5         4
# 5337      怖い  形容詞      5         1
# 5046     幅広い  形容詞      5         3
# 6757     温かい  形容詞      5         5
# 101     おかしい  形容詞      5         5
# 6020     明るい  形容詞      5         3
# 4015     可愛い  形容詞      5         1
# 8699      速い  形容詞      5         3
# 7977     苦しい  形容詞      4         4
# 8499      赤い  形容詞      4         4
# 239       こい  形容詞      4         4
# 636      やすい  形容詞      4         2
# 8604      辛い  形容詞      4         4
# 7577      細い  形容詞      3         3

# %%
overall.to_csv("femaleFigureSkater_text_overall.csv", index= False)

# %%
df= pd.read_csv("femaleFigureSkater_text_overall.csv")
df
# Out:
#        word pos  total  articles
# 0       選手権  名詞   7549      1539
# 1         位  名詞   7368      1050
# 2      スケート  名詞   5824      2488
# 3      シーズン  名詞   5005       903
# 4     フィギュア  名詞   4248      2466
# ...     ...  ..    ...       ...
# 9377  大阪府立大  名詞      1         1
# 9378     大邱  名詞      1         1
# 9379    大通り  名詞      1         1
# 9380     大輝  名詞      1         1
# 9381     安田  名詞      1         1
#
# [9382 rows x 4 columns]
